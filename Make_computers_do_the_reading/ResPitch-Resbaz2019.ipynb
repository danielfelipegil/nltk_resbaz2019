# %% [markdown]
# # what is NLTK?

# %% [markdown]
# <img src="res/NLTK.png"/>
# <a href='http://www.nltk.org'> NLTK (Natural Language ToolKit)</a><br><br>
# - NLTK is a leading platform for building Python programs to work with human language data<br>
# - Is intended to support research and teaching in NLP or closely related areas, including empirical linguistics, cognitive science, artificial intelligence, information retrieval, and machine learning.

# %% [markdown]
# ## Using NLTK
#
# * NLTK ([Natural Language Toolkit](http://www.nltk.org/)) is an external library,  you must import it first to use it:

# %%
import nltk

# %% [markdown]
# ### Access a corpus
# #### [Corpus](https://en.wikipedia.org/wiki/Text_corpus) = Large and structured set of texts
# (NLTK has some corpus built-in for you to test but also you can use our own)

# %%
nltk.corpus.brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %% [markdown]
# Here we will use or own :)<br>

# %% [markdown]
# <b>Corpus:</b> Friends TV Show, Season 10<br>
# <b>Goal:</b> Indentify the most important character of the season
#
# <img src='res/friends.jpg'>

# %%
# first, we will access the file with the transcripts
file = open('datasets/friends/season_10.txt', "r", encoding='UTF-8')
text = file.read()
text
# Out:
# '\n1001 - The One After Joey And Rachel Kiss\n\n\n\n\n1001 - The One After Joey And Rachel Kiss\n\nWritten by: Andrew Reich & Ted Cohen\n  Transcribed by: Coffee Mug\n\n[Scene: Barbados, Monica and Chandler\'s Room. They both enter from Ross\'s\n  room. Monica still has her big, frizzy hair.]\nMonica: Oh, the way you crushed Mike at ping pong was such\n  a turn-on.You wanna...? (plays with her finger on Chandlers chest)\nChandler: You know, I\'d love to, but I\'m a little tired.\nMonica: I\'ll put a pillowcase over my head.\nChandler: You\'re on!\n(they start to get ready, but then Phoebe enters through the door from Ross\'s\n  room)\nPhoebe: Hey!\nMonica: What\'s up?\nPhoebe: Well, okay, Mike\'s taking a shower, which by the\n  way there\'s  no law against. And then we\'re gonna grab some food, so if you\n  want...\n(there\'s a door slamming in Ross\'s room, and some indistinct murmuring)\nRoss: ... finally...\nPhoebe: Is that Ross?\nMonica: Yeah, you can hear everything through these stupid\n  walls.\nPhoebe: Sounds like he\'s with someone.\nChandler: He could be alone. This morning I heard him do\n  push-ups, and then talk to his triceps.\nMonica: Wait a minute, I think Phoebe\'s right. You know I\n  hear someone else in there with him.\n(they all put their ear against the wall to be able to hear what\'s\n  being said. We move to Ross\'s room where he and Charlie are kissing.)\nCharlie: Ooh... Dr. Geller!\nRoss: God, you\'re amazing... I didn\'t even have to ask you\n  to call me that.\nMonica: Oh my God, that\'s Charlie!\nChandler: She\'s cheating on Joey with Ross!\nPhoebe: Oh that tart... floozy... giant...\nMonica: I\'m not sure about this.\nPhoebe: Yeah, you\'re right. This is none of our business.\nMonica: No I\'m not sure that it\'s  the best way to hear\n  everything. Someone get me a glass!\nPhoebe: Oh, I\'m not gonna do this, okay? I\'m not gonna eavesdrop\n  on my friend.\nRachel: (through wall) Ooh... I love Barbados!  \n(Phoebe starts to listen at the other wall, where Rachel\'s room is. There,\n  Joey and Rachel are kissing.)\nJoey: Ooh... I can\'t believe I\'m kissing you. I\'m\n    kissing Rachel!\nRachel: I know, I\'m her!\n(they start to kiss again, and Phoebe turns to Chandler and Monica)\nPhoebe: (whispering) Rachel and Joey! It\'s Rachel and Joey!!!\nMonica: What?\nPhoebe: Get over here!\n(Chandler and Monica take a sprint to the other wall)\nRachel: ooh...\nChandler: Wow!\nMonica: (in her Monica-excited-way... TOO LOUD!) Oh my God,\n  I love how thin these walls are!\n(In the rooms next door, Joey, Rachel, Ross and Charlie stop kissing and try\n  to understand what the yelling was about. After a while they continue kissing.\n  We\'re back in Chandler and Monica\'s room. Monica has some of her own hair\n  stuffed in her mouth by Chandler.)\nMonica: (muffled) Thank you.\nOPENING CREDITS\n(Rachel and Joey\'s)\nRachel: Hey, you know, before you said\n    that nothing could happen between us? What changed?\nJoey: Well, I only said that because of Ross, you know. Then\n  I saw him kissing Charlie...\nRachel: What? Ross and Charlie? (Joey nods) Wow! She\'s really\n  making her way through the group, huh? Ah, who am I to talk?\n(Chandler and Monica\'s)\nMonica: I can\'t believe this. Rachel and Joey?\nChandler: How about the dinosaur twins in the other room?\n  No-one is manning that wall!\nMonica: I\'m on it!\nChandler: Anything?\nMonica: I think I hear curtains closing... \nPhoebe: We\'ve got shoes being kicked off over here.\nMonica: Bedsprings, unmistakable!\nChandler: You do realise  that\'s your brother?\nMonica: Not until you said it. Somebody switch! (Chandler\n  makes a clicking sound with his fingers and Phoebe runs to the other wall.\n  Monica returns to Chandlers wall.) Wait a minute... Ross and Charlie, Joey\n  and Rachel, Phoebe and Mike! We\'re the only people  leaving with the\n  same person we came with.\nChandler: That\'s not true. I came with Monica and I\'m leaving\n  with Weird Al.\nMonica ...

# %% [markdown]
# ### Preprocessing text = Make text ready to be analyzed

# %% [markdown]
# We will start [tokenizing](https://nlp.stanford.edu/IR-book/html/htmledition/tokenization-1.html) the text to preprocess

# %% [markdown]
# ##### Tokenization = cut the text into pieces like sentences or words
# <img src="res/token.jpg"/>

# %%
words=nltk.tokenize.word_tokenize(text)
words[:10]
# Out:
# ['1001', '-', 'The', 'One', 'After', 'Joey', 'And', 'Rachel', 'Kiss', '1001']

# %% [markdown]
# As a result we have a structure of data, called a list. <br/>

# %%
# get all the words from the corpus, this will give us a list containing all the words, 
# we can use python function len to count the total of words in the corpus.
len(words)
# Out:
# 105990

# %% [markdown]
# Now, let's see how many unique words we have:

# %%
# the python function set will return unique words. This is the lexical diversity of the corpus
len(set(words))
# Out:
# 5985

# %% [markdown]
# ### Analyse the text: Find your insights!
# text ready to be analyzed, let NLTK to read and count:

# %%
fd=nltk.FreqDist(words)
fd.most_common(10)
# Out:
# [(':', 5777),
#  (',', 5062),
#  ('.', 5039),
#  ('I', 2668),
#  ('!', 2449),
#  ('the', 1973),
#  ('you', 1922),
#  (')', 1919),
#  ('(', 1918),
#  ('?', 1811)]

# %% [markdown]
# :( not helpful?

# %% [markdown]
# <img src='res/idea.jpg'>
# Courtesy: <a href='https://www.istockphoto.com/au'>iStock</a>

# %% [markdown]
# What if we filter by nouns? NLTK is helpful for identifying Part-of-Speech like nouns, verbs and adjectives

# %%
tagged_words=nltk.pos_tag(words)
nouns=[]
for tagged_word in tagged_words:
    word=tagged_word[0].lower()
    tag=tagged_word[1]
    if tag.startswith('NNt'):
        nouns.append(word)
        
len(nouns)
# Out:
# 22796

# %%
fd=nltk.FreqDist(nouns)
fd.most_common(6)
# Out:
# [('ross', 1278),
#  ('joey', 1163),
#  ('chandler', 1076),
#  ('rachel', 1076),
#  ('monica', 1071),
#  ('phoebe', 966)]

# %%
fd.plot(6)

# %% [markdown]
# # Introducing the challenge
#
#
# Read all the ted talks until sept 2018 and investigate the most common words (nouns)<br>
# <img src='res/tedtalks.png'>

# %% [markdown]
# # What we learned today...

# %% [markdown]
# NLTK in 2 steps

# %% [markdown]
# ## 1) Access and preprocess your text
# We accessed a text and preprocess it filtering by nouns <br/>
#
# ## 2) Analyse and extract information
# We made an interpretation with the counts. <br/>

# %% [markdown]
# # If you use TEXT in your research, NLTK is relevant to you.
# # Come to the next sessions today and sign up for workshops/meetups to learn more!
# https://research.unimelb.edu.au/infrastructure/research-platform-services/training/nltk
